# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import

# %%
x1 = np.random.randn(1000,2)*1.4 + np.array([2,2])
x2 = np.random.randn(800,2)*3 + np.array([8,-3])
label = [0]*1000+[1]*800

x = np.vstack((x1,x2))

# %%
plt.scatter(x[:,0],x[:,1],c=label)

# %%
data = pd.read_csv('permits_and_population.csv')
# Out:
#        year   CBSA  permits house_type  population_est
# 0      2019  12620    266.0      Total          304296
# 1      2019  12620    216.0     Single          304296
# 2      2019  12620     50.0      Multi          304296
# 3      2019  12620      0.0         5+          304296
# 4      2019  12700    513.0      Total          425980
# ...     ...    ...      ...        ...             ...
# 15155  2010  48300      0.0         5+          222528
# 15156  2010  49420    624.0      Total          488512
# 15157  2010  49420    343.0     Single          488512
# 15158  2010  49420    281.0      Multi          488512
# 15159  2010  49420    274.0         5+          488512
#
# [15160 rows x 5 columns]

# %%
pd.read_csv('cbsa-population.csv', encoding = "ISO-8859-1")
# Out:
#        CBSA  MDIV    STCOU                  NAME  \
# 0     10180   NaN      NaN           Abilene, TX
# 1     10180   NaN  48059.0   Callahan County, TX
# 2     10180   NaN  48253.0      Jones County, TX
# 3     10180   NaN  48441.0     Taylor County, TX
# 4     10420   NaN      NaN             Akron, OH
# ...     ...   ...      ...                   ...
# 2792  49460   NaN  46135.0    Yankton County, SD
# 2793  49780   NaN      NaN        Zanesville, OH
# 2794  49780   NaN  39119.0  Muskingum County, OH
# 2795  49820   NaN      NaN            Zapata, TX
# 2796  49820   NaN  48505.0     Zapata County, TX
#
#                                LSAD  CENSUS2010POP  ESTIMATESBASE2010  \
# 0     Metropolitan Statistical Area         165252             165252
# 1              County or equivalent          13544              13545
# 2              County or equivalent          20202              20192
# 3              County or equivalent         131506             131515
# ...
